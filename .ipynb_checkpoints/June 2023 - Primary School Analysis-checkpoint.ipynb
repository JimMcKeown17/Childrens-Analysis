# %% [markdown]
# # Primary School June 2023 Results - w Sandwater
# #### English Total: 267, ixiXhosa Total (June): 243, ixiXhosa Total (June): 272

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import numpy as np
G3_colour = "#6DA9E4"
G2_colour = "#F7D060"
G1_colour = "#917FB3"
GR_colour = "#98D8AA"
ECD_colour = "#FF6D60"

# %%
children_all = pd.read_csv("20230712 - Children Results - English.csv")
children = children_all[children_all['Jan - Listen First Sound'].notna() & children_all['June - Listen First Sound'].notna()].copy()

exclude_schools = ['St Augustines', 'Zukisa', 'Khanyisa', 'Mzingisi', 'Phakamile']
children = children[~children['Schools'].isin(exclude_schools)].copy()

children['Jan - Total'] = children[['Jan - Listen First Sound', 'Jan - Listen Word','Jan - Phonics', 'Jan - Blends', 'Jan - Sight Words',
                                  'Jan - Read Sentences', 'Jan - Read Story', 'Jan - Story Comprehension',
                                  'Jan - Written Letters', 'Jan - Write Name', 'Jan - Write CVCs',
                                  'Jan - Write Sentences']].sum(axis=1,min_count=1)
children['June - Total'] = children[['June - Listen First Sound',
       'June - Listen Word','June - Phonics', 'June - Blends', 'June - Sight Words',
                                  'June - Read Sentences', 'June - Read Story', 'June - Story Comprehension',
                                  'June - Written Letters', 'June - Write Name', 'June - Write CVCs',
                                  'June - Write Sentences']].sum(axis=1,min_count=1)
children['June - Listen First Sound Improvement'] = children['June - Listen First Sound'] - children['Jan - Listen First Sound']
children['June - Listen Word Improvement'] = children['June - Listen Word'] - children['Jan - Listen Word']
children['June - Phonics Improvement'] = children['June - Phonics'] - children['Jan - Phonics']
children['June - Written Letters Improvement'] = children['June - Written Letters'] - children['Jan - Written Letters']
children["Jan - Sounds Total"] =  children["Jan - Listen First Sound"] + children["Jan - Listen Word"]
children["June - Sounds Total"] =  children["June - Listen First Sound"] + children["June - Listen Word"]
children["June - Sounds Total Improvement"] = children["June - Sounds Total"] - children["Jan - Sounds Total"]
children["June - Blends Improvement"] = children["June - Blends"] - children["Jan - Blends"]
children["June - Read Sentences Improvement"] = children["June - Read Sentences"] - children["Jan - Read Sentences"]
children["June - Read Story Improvement"] = children["June - Read Story"] - children["Jan - Read Story"]
children["June - Sight Words Improvement"] = children["June - Sight Words"] - children["Jan - Sight Words"]
children["June - Write Sentence Improvement"] = children["June - Write Sentences"] - children["Jan - Write Sentences"]
children["June - Write CVCs Improvement"] = children["June - Write CVCs"] - children["Jan - Write CVCs"]
children["June - Total Improvement"] = children["June - Total"] - children["Jan - Total"]
# Sounds and Phonics Total is 49
children["Jan - Sounds and Phonics"] = children["Jan - Listen First Sound"] + children["Jan - Listen Word"] + children['Jan - Phonics']
# Reading total is 128
children["Jan - Reading"] = children["Jan - Blends"] + children["Jan - Sight Words"] + children['Jan - Read Sentences'] + children["Jan - Read Story"] + children["Jan - Story Comprehension"]
# Writing total is 87
children["Jan - Writing"] = children['Jan - Written Letters'] + children["Jan - Write CVCs"] + children["Jan - Write Sentences"]
# Sounds and Phonics Total is 49
children["June - Sounds and Phonics"] = children["June - Listen First Sound"] + children["June - Listen Word"] + children['June - Phonics']
# Reading total is 128
children["June - Reading"] = children["June - Blends"] + children["June - Sight Words"] + children['June - Read Sentences'] + children["June - Read Story"] + children["June - Story Comprehension"]
# Writing total is 87
children["June - Writing"] = children['June - Written Letters'] + children["June - Write CVCs"] + children["June - Write Sentences"]

children["June - Sounds and Phonics Improvement"] = children["June - Sounds and Phonics"] - children["Jan - Sounds and Phonics"]
children["June - Reading Improvement"] = children["June - Reading"] - children["Jan - Reading"]
children["June - Writing Improvement"] = children["June - Writing"] - children["Jan - Writing"] 

children['Graduate_Status'] = children['June - Total'].apply(lambda x: 'Graduate' if x > 224 else np.nan)

improvement_columns = ["June - Listen First Sound Improvement","June - Listen Word Improvement", "June - Phonics Improvement","June - Blends Improvement", "June - Sight Words Improvement", "June - Read Sentences Improvement", "June - Read Story Improvement", "June - Written Letters Improvement", "June - Write CVCs Improvement", "June - Write Sentence Improvement", "June - Total Improvement" ]
improvement_columns_detailed = ["Full Name", 'Schools', 'Grade', 'LC Name',"June - Listen First Sound Improvement","June - Phonics Improvement","June - Sight Words Improvement", "June - Read Story Improvement", "June - Written Letters Improvement", "June - Write Sentence Improvement", "June - Total Improvement" ]

# %%
primary = children[children['Grade'] != 'PreR']
primary_on = primary[primary['On The Programme'] == 'Yes']
gbo = primary.groupby('Schools')
gbo_on = primary_on.groupby('Schools')

GradeR = children[children['Grade'] == 'Grade R']
GradeR_on = GradeR[GradeR['On The Programme'] == 'Yes']
gboR = GradeR.groupby('Schools')
gboR_on = GradeR_on.groupby('Schools')

Grade1 = children[children['Grade'] == 'Grade 1']
Grade1_on = Grade1[Grade1['On The Programme'] == 'Yes']
gbo1 = Grade1.groupby('Schools')
gbo1_on = Grade1_on.groupby('Schools')

Grade2 = children[children['Grade'] == 'Grade 2']
Grade2_on = Grade2[Grade2['On The Programme'] == 'Yes']
gbo2 = Grade2.groupby('Schools')
gbo2_on = Grade2_on.groupby('Schools')

Grade3 = children[children['Grade'] == 'Grade 3']
Grade3_on = Grade3[Grade3['On The Programme'] == 'Yes']
gbo3 = Grade3.groupby('Schools')
gbo3_on = Grade3_on.groupby('Schools')

# %% [markdown]
# # % of Children Assessed

# %%
primary_all = children_all[children_all['Grade'] != 'PreR']
primary_on_all = primary_all[primary_all['On The Programme'] == 'Yes']
gbo_all = primary_all.groupby('Schools')
gbo_on_all = primary_on_all.groupby('Schools')

total_children = gbo_on_all['Full Name'].count()
total_children_assessed = gbo_on_all['June - Phonics'].count()

percent_assessed = (total_children_assessed / total_children) * 100


df_assessed = pd.DataFrame({'Number of Children': total_children, 
                          'Number of Children Assessed': total_children_assessed, 
                          'Percentage Assessed': percent_assessed})
df_assessed.sort_values('Percentage Assessed', ascending=False)
# Out:
#                Number of Children  Number of Children Assessed  \
# Schools
# Astra                          55                           55
# Fumisukoma                    141                          140
# Charles Duna                   96                           95
# Isaac Booi                    144                          142
# Ben Sinuka                     48                           47
# Ebongweni                      47                           46
# Aaron Gqadu                    42                           41
# Seyisi                        125                          121
# Empumalanga                    60                           57
# Molefe                         46                           40
# Sandwater                      46                           32
# Clarkson                      131                            0
# Khanyisa                       24                            0
# Mzingisi                       45                            0
# Phakamile                      48                            0
# St Augustines                  32                            0
# Zukisa                         32                            0
#
#                Percentage Assessed
# Schools
# Astra                   100.000000
# Fumisukoma               99.290780
# Charles Duna             98.958333
# Isaac Booi               98.611111
# Ben Sinuka               97.916667
# Ebongweni                97.872340
# Aaron Gqadu              97.619048
# Seyisi                   96.800000
# Empumalanga              95.000000
# Molefe                   86.956522
# Sandwater                69.565217
# Clarkson                  0.000000
# Khanyisa                  0.000000
# Mzingisi                  0.000000
# Phakamile                 0.000000
# St Augustines             0.000000
# Zukisa                    0.000000

# %%
df_all = primary.groupby('Schools')['On The Programme'].value_counts()
pd.set_option('display.max_rows', None)
df_all
# Out:
# Schools       On The Programme
# Aaron Gqadu   Yes                  41
#               No                    2
# Astra         Yes                  55
#               No                    1
# Ben Sinuka    Yes                  47
# Charles Duna  Yes                  95
#               No                    1
# Ebongweni     Yes                  46
#               No                    2
# Empumalanga   Yes                  57
# Fumisukoma    Yes                 140
#               No                    1
# Isaac Booi    Yes                 142
# Molefe        Yes                  38
# Sandwater     Yes                  32
# Seyisi        Yes                 121
#               No                    8
# Name: On The Programme, dtype: int64

# %% [markdown]
# # Average Number of Sessions per Child

# %%
df = gbo['Total Sessions'].mean()
df.sort_values(ascending=False).plot(kind="bar")
# Out:
# <Axes: xlabel='Schools'>

# %% [markdown]
# # Number of Sessions Kids on the Programme Received

# %%
import seaborn as sns

plt.figure(figsize=(15, 10))
sns.histplot(data=primary_on, x="Total Sessions", hue="Schools")
plt.show()

# %% [markdown]
# # Whole School Results

# %% [markdown]
# ### All Grades Avg Improvement By School

# %%
# First, calculate the order of schools based on the mean of 'June - Total Improvement'
order = primary_on.groupby('Schools')['June - Total Improvement'].mean().sort_values(ascending=False).index

fig, ax = plt.subplots(figsize=(15, 6))

# Then, pass this order to the 'order' parameter in the barplot function
sns.barplot(data=primary_on, x='Schools', y='June - Total Improvement', order=order, errorbar=None, ax=ax, palette="rocket")
plt.title("Average Progress of Children by School")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### All Grades Avg Improvement in Table

# %%
df_improvement = gbo_on[improvement_columns].mean()
df_improvement.sort_values('June - Total Improvement', ascending=False)
# Out:
#               June - Listen First Sound Improvement  \
# Schools
# Ebongweni                                  5.043478
# Fumisukoma                                 2.021429
# Seyisi                                     2.380165
# Ben Sinuka                                 1.829787
# Molefe                                     3.605263
# Charles Duna                               2.684211
# Empumalanga                                1.807018
# Astra                                      1.345455
# Isaac Booi                                 1.211268
# Aaron Gqadu                                2.658537
# Sandwater                                  1.625000
#
#               June - Listen Word Improvement  June - Phonics Improvement  \
# Schools
# Ebongweni                           4.869565                   11.478261
# Fumisukoma                          1.971429                    5.335714
# Seyisi                              3.231405                    8.173554
# Ben Sinuka                          1.468085                    4.446809
# Molefe                              3.500000                    7.710526
# Charles Duna                        1.473684                    8.105263
# Empumalanga                         1.631579                   10.508772
# Astra                               1.890909                    4.745455
# Isaac Booi                          2.070423                    3.633803
# Aaron Gqadu                         1.609756                    5.000000
# Sandwater                           1.468750                    3.218750
#
#               June - Blends Improvement  June - Sight Words Improvement  \
# Schools
# Ebongweni                      1.391304                        2.608696
# Fumisukoma                     1.542857                        4.607143
# Seyisi                         1.677686                        3.752066
# Ben Sinuka                     1.553191                        4.744681
# Molefe                         1.631579                        1.973684
# Charles Duna                   0.600000                        1.473684
# Empumalanga                    1.561404                        1.614035
# Astra                          1.872727                        2.672727
# Isaac Booi                     0.577465                        1.225352
# Aaron Gqadu                    0.658537                        0.975610
# Sandwater                      0.937500                        1.156250
#
#               June - Read Sentences Improvement  \
# Schools
# Ebongweni                              1.478261
# Fumisukoma                             2.135714
# Seyisi                                 0.793388
# Ben Sinuka                             3.085106
# Molefe                                 1.184211
# Charles Duna                           1.010526
# Empumalanga                            1.333333
# Astra                                  1.945455
# Isaac Booi                             0.746479
# Aaron Gqadu                            0.146341
# Sandwater                              0.625000
#
#               June - Read Story Improvement  \
# Schools
# Ebongweni                          1.586957
# Fumisukoma                        13.150000
# Seyisi                             7.041322
# Ben Sinuka                         8.702128
# Molefe                             0.157895
# Charles Duna                       1.757895
# Empumalanga                        3.087719
# Astra                              3.309091
# Isaac Booi                         2.161972
# Aaron Gqadu                        0.048780
# Sandwater                          0.000000
#
#               June - Written Letters Improvement  \
# Schools
# Ebongweni                               8.565217
# Fumisukoma                              4.035714
# Seyisi                                  4.900826
# Ben Sinuka                              3.148936
# Molefe                                  8.236842
# Charles Duna                            6.789474
# Empumalanga                             7.596491
# Astra                                   3.981818
# Isaac Booi                              3.373239
# Aaron Gqadu                             4.268293
# Sandwater                               1.625000
#
#               June - Write CVCs Improvement  \
# Schools
# Ebongweni                          4.347826
# Fumisukoma                         1.964286
# Seyisi                             2.115702
# Ben Sinuka                         1.255319
# Molefe                             4.289474
# Charles Duna                       2.431579
# Empumalanga                        2.929825
# Astra                              2.636364
# Isaac Booi                         1.570423
# Aaron Gqadu                        1.853659
# Sandwater                          1.562500
#
#               June - Write Sentence Improvement  June - Total Improvement
# Schools
# Ebongweni                              3.630435                 46.065217
# Fumisukoma                             7.942857                 45.335714
# Seyisi                                 2.578512                 37.239669
# Ben Sinuka                             5.297872                 36.148936
# Molefe                                 2.447368                 35.368421
# Charles Duna                           5.936842                 32.968421
# Empumalanga                            0.428571                 32.824561
# Astra                                  7.818182                 32.381818
# Isaac Booi                             2.091549                 19.028169
# Aaron Gqadu                            1.073171                 18.902439
# Sandwater                              4.406250                 16.656250

# %% [markdown]
# # Grade R Results

# %% [markdown]
# ### GR Jan and June results side-by-side

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Groupby 'Schools' and calculate the mean, then sort by 'June - Total'
GradeR_on_grouped = GradeR_on.groupby('Schools')[['Jan - Total', 'June - Total']].mean().sort_values('June - Total', ascending=False).reset_index()

# Melt the DataFrame to a "long" format suitable for seaborn
melted = GradeR_on_grouped.melt(id_vars='Schools', var_name='Month', value_name='Average Total Score')

# Plot the data
plt.figure(figsize=(15, 6))
sns.barplot(data=melted, x='Schools', y='Average Total Score', hue='Month')
plt.title('Average Total Scores for January and June')
plt.xlabel('Schools')
plt.ylabel('Average Total Score')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### GR Improvement by School

# %%
# First, calculate the order of schools based on the mean of 'June - Total Improvement'
order = GradeR_on.groupby('Schools')['June - Total Improvement'].mean().sort_values(ascending=False).index

fig, ax = plt.subplots(figsize=(15, 6))

# Then, pass this order to the 'order' parameter in the barplot function
sns.barplot(data=GradeR_on, x='Schools', y='June - Total Improvement', order=order, errorbar=None, ax=ax, palette="rocket")
plt.title("Average Progress of Children by School")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### GR Improvement Results in Table

# %%
df_GradeR_improvement = gboR_on[improvement_columns].mean()
df_GradeR_improvement.sort_values('June - Total Improvement', ascending=False)
# Out:
#               June - Listen First Sound Improvement  \
# Schools
# Ebongweni                                  6.450000
# Seyisi                                     4.920000
# Charles Duna                               2.928571
# Molefe                                     4.272727
# Fumisukoma                                 5.133333
# Empumalanga                                2.625000
# Aaron Gqadu                                3.333333
# Ben Sinuka                                 4.571429
# Isaac Booi                                 2.282609
# Astra                                      2.153846
# Sandwater                                  1.600000
#
#               June - Listen Word Improvement  June - Phonics Improvement  \
# Schools
# Ebongweni                           3.950000                    7.550000
# Seyisi                              3.960000                    9.080000
# Charles Duna                        0.142857                    7.250000
# Molefe                              1.727273                    4.272727
# Fumisukoma                          1.266667                    5.200000
# Empumalanga                         0.937500                    8.187500
# Aaron Gqadu                         0.944444                    6.333333
# Ben Sinuka                          5.000000                    1.857143
# Isaac Booi                          1.586957                    3.326087
# Astra                               1.000000                    3.538462
# Sandwater                          -0.100000                    0.000000
#
#               June - Blends Improvement  June - Sight Words Improvement  \
# Schools
# Ebongweni                      0.450000                        1.000000
# Seyisi                         0.120000                        0.000000
# Charles Duna                   0.071429                        0.125000
# Molefe                         0.272727                        1.000000
# Fumisukoma                     0.333333                        0.133333
# Empumalanga                    0.062500                        0.062500
# Aaron Gqadu                    0.055556                        0.500000
# Ben Sinuka                     0.000000                        0.000000
# Isaac Booi                     0.043478                        0.086957
# Astra                          0.000000                        0.076923
# Sandwater                      0.000000                        0.000000
#
#               June - Read Sentences Improvement  \
# Schools
# Ebongweni                              0.400000
# Seyisi                                 0.000000
# Charles Duna                           0.089286
# Molefe                                 0.000000
# Fumisukoma                             0.133333
# Empumalanga                            0.000000
# Aaron Gqadu                            0.000000
# Ben Sinuka                             0.142857
# Isaac Booi                            -0.021739
# Astra                                  0.000000
# Sandwater                             -0.200000
#
#               June - Read Story Improvement  \
# Schools
# Ebongweni                          0.100000
# Seyisi                             0.000000
# Charles Duna                       0.000000
# Molefe                             0.000000
# Fumisukoma                         0.000000
# Empumalanga                        0.000000
# Aaron Gqadu                        0.000000
# Ben Sinuka                         0.142857
# Isaac Booi                         0.000000
# Astra                              0.000000
# Sandwater                          0.000000
#
#               June - Written Letters Improvement  \
# Schools
# Ebongweni                               6.200000
# Seyisi                                  3.800000
# Charles Duna                            6.410714
# Molefe                                  4.545455
# Fumisukoma                              3.666667
# Empumalanga                             3.875000
# Aaron Gqadu                             3.277778
# Ben Sinuka                              0.142857
# Isaac Booi                              3.565217
# Astra                                   2.538462
# Sandwater                               0.100000
#
#               June - Write CVCs Improvement  \
# Schools
# Ebongweni                          0.850000
# Seyisi                             0.680000
# Charles Duna                       1.214286
# Molefe                             0.818182
# Fumisukoma                         0.333333
# Empumalanga                        0.437500
# Aaron Gqadu                        0.555556
# Ben Sinuka                         0.285714
# Isaac Booi                         0.673913
# Astra                              0.000000
# Sandwater                          0.000000
#
#               June - Write Sentence Improvement  June - Total Improvement
# Schools
# Ebongweni                              0.450000                 28.800000
# Seyisi                                 0.000000                 23.440000
# Charles Duna                           0.589286                 19.857143
# Molefe                                 0.000000                 17.636364
# Fumisukoma                             0.000000                 17.466667
# Empumalanga                            0.000000                 16.500000
# Aaron Gqadu                            0.277778                 15.722222
# Ben Sinuka                             0.000000                 13.142857
# Isaac Booi                             0.173913                 12.586957
# Astra                                  0.000000                  9.769231
# Sandwater                              0.000000                  1.600000

# %% [markdown]
# ### GR Improvement Results of Children with 15 or More Sessions

# %%
GradeR_qualify = GradeR[(GradeR['On The Programme'] == 'Yes') & (GradeR['Total Sessions'] > 15)]
df_GradeR_qualify_improvement = GradeR_qualify.groupby('Schools')[improvement_columns].mean()
df_GradeR_qualify_improvement.sort_values('June - Total Improvement', ascending=False)
# Out:
#               June - Listen First Sound Improvement  \
# Schools
# Ebongweni                                  5.833333
# Charles Duna                               1.000000
# Molefe                                     4.200000
# Seyisi                                     5.142857
# Aaron Gqadu                                4.727273
# Empumalanga                                3.000000
# Fumisukoma                                 5.692308
# Isaac Booi                                 2.279070
# Sandwater                                  1.600000
#
#               June - Listen Word Improvement  June - Phonics Improvement  \
# Schools
# Ebongweni                           4.833333                   12.166667
# Charles Duna                        1.500000                   12.500000
# Molefe                              2.800000                    6.600000
# Seyisi                              3.642857                    8.428571
# Aaron Gqadu                         1.636364                    7.727273
# Empumalanga                         1.636364                    9.727273
# Fumisukoma                          1.461538                    4.769231
# Isaac Booi                          1.697674                    3.534884
# Sandwater                          -0.100000                    0.000000
#
#               June - Blends Improvement  June - Sight Words Improvement  \
# Schools
# Ebongweni                      1.500000                        1.333333
# Charles Duna                   0.000000                        0.000000
# Molefe                         0.600000                        2.200000
# Seyisi                         0.214286                        0.000000
# Aaron Gqadu                    0.090909                        0.818182
# Empumalanga                    0.090909                        0.090909
# Fumisukoma                     0.307692                        0.153846
# Isaac Booi                     0.046512                        0.093023
# Sandwater                      0.000000                        0.000000
#
#               June - Read Sentences Improvement  \
# Schools
# Ebongweni                              1.000000
# Charles Duna                           0.000000
# Molefe                                 0.000000
# Seyisi                                 0.000000
# Aaron Gqadu                            0.000000
# Empumalanga                            0.000000
# Fumisukoma                             0.153846
# Isaac Booi                            -0.023256
# Sandwater                             -0.200000
#
#               June - Read Story Improvement  \
# Schools
# Ebongweni                          0.333333
# Charles Duna                       0.000000
# Molefe                             0.000000
# Seyisi                             0.000000
# Aaron Gqadu                        0.000000
# Empumalanga                        0.000000
# Fumisukoma                         0.000000
# Isaac Booi                         0.000000
# Sandwater                          0.000000
#
#               June - Written Letters Improvement  \
# Schools
# Ebongweni                              10.500000
# Charles Duna                           15.000000
# Molefe                                  8.200000
# Seyisi                                  3.071429
# Aaron Gqadu                             4.000000
# Empumalanga                             4.454545
# Fumisukoma                              3.230769
# Isaac Booi                              3.813953
# Sandwater                               0.100000
#
#               June - Write CVCs Improvement  \
# Schools
# Ebongweni                          3.166667
# Charles Duna                       6.500000
# Molefe                             1.800000
# Seyisi                             0.857143
# Aaron Gqadu                        0.909091
# Empumalanga                        0.454545
# Fumisukoma                         0.307692
# Isaac Booi                         0.720930
# Sandwater                          0.000000
#
#               June - Write Sentence Improvement  June - Total Improvement
# Schools
# Ebongweni                              1.500000                 43.166667
# Charles Duna                           0.000000                 36.500000
# Molefe                                 0.000000                 27.200000
# Seyisi                                 0.000000                 22.428571
# Aaron Gqadu                            0.454545                 20.818182
# Empumalanga                            0.000000                 19.909091
# Fumisukoma                             0.000000                 17.538462
# Isaac Booi                             0.186047                 13.279070
# Sandwater                              0.000000                  1.600000

# %% [markdown]
# # Grade 1 Summary

# %% [markdown]
# ### G1 Jan and June results side-by-side

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Groupby 'Schools' and calculate the mean, then sort by 'June - Total'
Grade1_on_grouped = Grade1_on.groupby('Schools')[['Jan - Total', 'June - Total']].mean().sort_values('June - Total', ascending=False).reset_index()

# Melt the DataFrame to a "long" format suitable for seaborn
melted = Grade1_on_grouped.melt(id_vars='Schools', var_name='Month', value_name='Average Total Score')

# Plot the data
plt.figure(figsize=(15, 6))
sns.barplot(data=melted, x='Schools', y='Average Total Score', hue='Month')
plt.title('Average Total Scores for January and June')
plt.xlabel('Schools')
plt.ylabel('Average Total Score')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### G1 Improvement By School

# %%
# First, calculate the order of schools based on the mean of 'June - Total Improvement'
order = Grade1_on.groupby('Schools')['June - Total Improvement'].mean().sort_values(ascending=False).index

fig, ax = plt.subplots(figsize=(15, 6))

# Then, pass this order to the 'order' parameter in the barplot function
sns.barplot(data=Grade1_on, x='Schools', y='June - Total Improvement', order=order, errorbar=None, ax=ax, palette="rocket")
plt.title("Average Progress of Children by School")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### G1 Improvement Results in Table

# %%
df_Grade1_improvement = gbo1_on[improvement_columns].mean()
df_Grade1_improvement.sort_values('June - Total Improvement', ascending=False)
# Out:
#               June - Listen First Sound Improvement  \
# Schools
# Ebongweni                                  3.961538
# Charles Duna                               2.333333
# Molefe                                     3.333333
# Astra                                      1.095238
# Empumalanga                                1.487805
# Fumisukoma                                 2.924528
# Sandwater                                  2.888889
# Seyisi                                     2.319149
# Ben Sinuka                                 3.888889
# Aaron Gqadu                                2.130435
# Isaac Booi                                 1.315789
#
#               June - Listen Word Improvement  June - Phonics Improvement  \
# Schools
# Ebongweni                           5.576923                   14.500000
# Charles Duna                        3.384615                    9.333333
# Molefe                              4.222222                    9.111111
# Astra                               2.166667                    5.119048
# Empumalanga                         1.902439                   11.414634
# Fumisukoma                          3.150943                    9.452830
# Sandwater                           4.555556                    8.666667
# Seyisi                              4.191489                    8.000000
# Ben Sinuka                          3.666667                    9.888889
# Aaron Gqadu                         2.130435                    3.956522
# Isaac Booi                          2.973684                    5.473684
#
#               June - Blends Improvement  June - Sight Words Improvement  \
# Schools
# Ebongweni                      2.115385                        3.846154
# Charles Duna                   1.358974                        3.410256
# Molefe                         2.185185                        2.370370
# Astra                          2.452381                        3.476190
# Empumalanga                    2.146341                        2.219512
# Fumisukoma                     1.773585                        2.698113
# Sandwater                      1.333333                       -0.222222
# Seyisi                         1.446809                        3.446809
# Ben Sinuka                     1.666667                        0.666667
# Aaron Gqadu                    1.130435                        1.347826
# Isaac Booi                     0.447368                        0.578947
#
#               June - Read Sentences Improvement  \
# Schools
# Ebongweni                              2.307692
# Charles Duna                           2.333333
# Molefe                                 1.666667
# Astra                                  2.547619
# Empumalanga                            1.853659
# Fumisukoma                             1.943396
# Sandwater                             -0.555556
# Seyisi                                 0.468085
# Ben Sinuka                             0.000000
# Aaron Gqadu                            0.260870
# Isaac Booi                             0.184211
#
#               June - Read Story Improvement  \
# Schools
# Ebongweni                          2.730769
# Charles Duna                       4.282051
# Molefe                             0.222222
# Astra                              4.333333
# Empumalanga                        4.292683
# Fumisukoma                         2.245283
# Sandwater                          0.000000
# Seyisi                             0.042553
# Ben Sinuka                         0.000000
# Aaron Gqadu                        0.086957
# Isaac Booi                         0.263158
#
#               June - Written Letters Improvement  \
# Schools
# Ebongweni                              10.384615
# Charles Duna                            7.333333
# Molefe                                  9.740741
# Astra                                   4.428571
# Empumalanga                             9.048780
# Fumisukoma                              7.132075
# Sandwater                               5.111111
# Seyisi                                  6.361702
# Ben Sinuka                              6.777778
# Aaron Gqadu                             5.043478
# Isaac Booi                              5.684211
#
#               June - Write CVCs Improvement  \
# Schools
# Ebongweni                          7.038462
# Charles Duna                       4.179487
# Molefe                             5.703704
# Astra                              3.452381
# Empumalanga                        3.902439
# Fumisukoma                         4.490566
# Sandwater                          3.777778
# Seyisi                             4.085106
# Ben Sinuka                         2.777778
# Aaron Gqadu                        2.869565
# Isaac Booi                         2.631579
#
#               June - Write Sentence Improvement  June - Total Improvement
# Schools
# Ebongweni                              6.076923                 59.346154
# Charles Duna                          13.615385                 51.794872
# Molefe                                 3.444444                 42.592593
# Astra                                 10.238095                 39.380952
# Empumalanga                            0.600000                 39.195122
# Fumisukoma                             2.415094                 38.584906
# Sandwater                              9.333333                 35.222222
# Seyisi                                 1.510638                 32.170213
# Ben Sinuka                             0.000000                 30.222222
# Aaron Gqadu                            1.695652                 21.391304
# Isaac Booi                             1.078947                 20.842105

# %% [markdown]
# # Grade 2 Summary

# %% [markdown]
# ### G2 Jan and June results side-by-side

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Groupby 'Schools' and calculate the mean, then sort by 'June - Total'
Grade2_on_grouped = Grade2_on.groupby('Schools')[['Jan - Total', 'June - Total']].mean().sort_values('June - Total', ascending=False).reset_index()

# Melt the DataFrame to a "long" format suitable for seaborn
melted = Grade2_on_grouped.melt(id_vars='Schools', var_name='Month', value_name='Average Total Score')

# Plot the data
plt.figure(figsize=(15, 6))
sns.barplot(data=melted, x='Schools', y='Average Total Score', hue='Month')
plt.title('Average Total Scores for January and June')
plt.xlabel('Schools')
plt.ylabel('Average Total Score')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### G2 Improvement Results

# %%
# First, calculate the order of schools based on the mean of 'June - Total Improvement'
order = Grade2_on.groupby('Schools')['June - Total Improvement'].mean().sort_values(ascending=False).index

fig, ax = plt.subplots(figsize=(15, 6))

# Then, pass this order to the 'order' parameter in the barplot function
sns.barplot(data=Grade2_on, x='Schools', y='June - Total Improvement', order=order, errorbar=None, ax=ax, palette="rocket")
plt.title("Average Progress of Children by School")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### G2 Improvement Results in Table

# %%
df_Grade2_improvement = gbo2_on[improvement_columns].mean()
df_Grade2_improvement.sort_values('June - Total Improvement', ascending=False)
# Out:
#             June - Listen First Sound Improvement  \
# Schools
# Fumisukoma                               0.371429
# Seyisi                                   0.921053
# Ben Sinuka                               0.857143
# Isaac Booi                               0.305556
# Sandwater                                0.769231
#
#             June - Listen Word Improvement  June - Phonics Improvement  \
# Schools
# Fumisukoma                        1.114286                    2.571429
# Seyisi                            1.342105                    7.763158
# Ben Sinuka                        0.928571                    3.142857
# Isaac Booi                        2.166667                    2.694444
# Sandwater                         0.538462                    1.923077
#
#             June - Blends Improvement  June - Sight Words Improvement  \
# Schools
# Fumisukoma                   1.600000                        9.085714
# Seyisi                       2.578947                        5.605263
# Ben Sinuka                   2.357143                        5.714286
# Isaac Booi                   1.416667                        1.666667
# Sandwater                    1.384615                        3.000000
#
#             June - Read Sentences Improvement  June - Read Story Improvement  \
# Schools
# Fumisukoma                           3.600000                      21.171429
# Seyisi                               1.421053                      16.315789
# Ben Sinuka                           3.857143                       9.571429
# Isaac Booi                           1.333333                       5.166667
# Sandwater                            2.076923                       0.000000
#
#             June - Written Letters Improvement  June - Write CVCs Improvement  \
# Schools
# Fumisukoma                            1.742857                       0.714286
# Seyisi                                4.394737                       1.000000
# Ben Sinuka                            3.785714                       1.714286
# Isaac Booi                            1.944444                       2.388889
# Sandwater                             0.384615                       1.230769
#
#             June - Write Sentence Improvement  June - Total Improvement
# Schools
# Fumisukoma                          14.114286                 56.428571
# Seyisi                               4.184211                 46.210526
# Ben Sinuka                           9.071429                 41.285714
# Isaac Booi                           3.333333                 22.500000
# Sandwater                            4.384615                 15.384615

# %% [markdown]
# # Grade 3 Summary

# %% [markdown]
# ### G3 Jan and June results side-by-side

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Groupby 'Schools' and calculate the mean, then sort by 'June - Total'
Grade3_on_grouped = Grade3_on.groupby('Schools')[['Jan - Total', 'June - Total']].mean().sort_values('June - Total', ascending=False).reset_index()

# Melt the DataFrame to a "long" format suitable for seaborn
melted = Grade3_on_grouped.melt(id_vars='Schools', var_name='Month', value_name='Average Total Score')

# Plot the data
plt.figure(figsize=(15, 6))
sns.barplot(data=melted, x='Schools', y='Average Total Score', hue='Month')
plt.title('Average Total Scores for January and June')
plt.xlabel('Schools')
plt.ylabel('Average Total Score')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### G3 Improvement Results

# %%
# First, calculate the order of schools based on the mean of 'June - Total Improvement'
order = Grade3_on.groupby('Schools')['June - Total Improvement'].mean().sort_values(ascending=False).index

fig, ax = plt.subplots(figsize=(15, 6))

# Then, pass this order to the 'order' parameter in the barplot function
sns.barplot(data=Grade3_on, x='Schools', y='June - Total Improvement', order=order, errorbar=None, ax=ax, palette="rocket")
plt.title("Average Progress of Children by School")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 
# Molefe                              4.000000                    8.538462
# Empumalanga                         1.400000                   12.971429
# Fumisukoma                          2.458333                    9.937500
# Ben Sinuka                          4.352941                    5.941176
# Charles Duna                        0.753846                    9.169231
# Astra                               1.318182                    7.272727
# Sandwater                           2.187500                    5.375000
# Aaron Gqadu                         1.031250                    5.468750
# Isaac Booi                          1.925373                    5.089552
#
#               June - Sounds and Phonics Improvement
# Schools
# Ebongweni                                 23.000000
# Seyisi                                    19.785714
# Molefe                                    17.269231
# Empumalanga                               17.057143
# Fumisukoma                                17.000000
# Ben Sinuka                                14.705882
# Charles Duna                              13.138462
# Astra                                     11.772727
# Sandwater                                 10.812500
# Aaron Gqadu                                9.968750
# Isaac Booi                                 9.104478

# %% [markdown]
# # Early Readers Performance
# #### Checking the performance of children with a Reading Score between 10% and 39%

# %% [markdown]
# ### Number of Early Readers

# %%
df_early_readers = primary[(primary['On The Programme'] == 'Yes') & (primary['Jan - Sounds and Phonics'] > 35) & (primary['Jan - Reading'] > 13) & (primary['Jan - Reading'] < 50)]
df_early_readers.groupby(['Grade', 'Schools'])['Mcode'].count()
# Out:
# Grade    Schools
# Grade 1  Astra           3
#          Ebongweni       1
#          Empumalanga     1
#          Sandwater       1
# Grade 2  Ben Sinuka      2
#          Fumisukoma     15
#          Isaac Booi      5
#          Sandwater       4
#          Seyisi          6
# Grade 3  Ben Sinuka      6
#          Fumisukoma      6
#          Isaac Booi      7
#          Seyisi          3
# Name: Mcode, dtype: int64

# %% [markdown]
# ### Early Readers Performance

# %%
# Reading total is 128
# children["June - Reading"] = children["June - Blends"] + children["June - Sight Words"] + children['June - Read Sentences'] + children["June - Read Story"] + children["June - Story Comprehension"]

df_early_readers = primary[(primary['On The Programme'] == 'Yes') & (primary['Jan - Sounds and Phonics'] > 35) & (primary['Jan - Reading'] > 13) & (primary['Jan - Reading'] < 50)]
columns = ["June - Blends Improvement", "June - Sight Words Improvement", 'June - Read Sentences Improvement', "June - Read Story Improvement", "June - Reading Improvement"]
df_early_readers.groupby('Schools')[columns].mean().sort_values("June - Reading Improvement", ascending=False)
# Out:
#              June - Blends Improvement  June - Sight Words Improvement  \
# Schools
# Seyisi                        2.111111                       12.555556
# Astra                         4.666667                        7.333333
# Fumisukoma                    1.238095                        8.047619
# Ben Sinuka                    1.125000                        5.625000
# Isaac Booi                    0.500000                        5.583333
# Ebongweni                     4.000000                        8.000000
# Sandwater                     1.000000                        3.400000
# Empumalanga                   0.000000                      -13.000000
#
#              June - Read Sentences Improvement  June - Read Story Improvement  \
# Schools
# Seyisi                                5.888889                      56.222222
# Astra                                 4.000000                      30.666667
# Fumisukoma                            2.904762                      30.380952
# Ben Sinuka                            6.375000                      16.250000
# Isaac Booi                            0.916667                      17.250000
# Ebongweni                             3.000000                      -1.000000
# Sandwater                             0.400000                       0.000000
# Empumalanga                         -10.000000                       0.000000
#
#              June - Reading Improvement
# Schools
# Seyisi                        78.444444
# Astra                         48.000000
# Fumisukoma                    43.000000
# Ben Sinuka                    29.750000
# Isaac Booi                    24.333333
# Ebongweni                     14.000000
# Sandwater                      4.800000
# Empumalanga                  -23.000000

# %% [markdown]
# # Good Readers Performance
# ##### Definted as knowing 90% of their phonics/sounds and having an initial reading score above 40%

# %% [markdown]
# ### Number of 'Good Readers'

# %%
df_good_readers = primary[(primary['On The Programme'] == 'Yes') & (primary['Jan - Sounds and Phonics'] > 35) & (primary['Jan - Reading'] >= 50)]
df_good_readers.groupby(['Grade','Schools'])['Mcode'].count()
# Out:
# Grade    Schools
# Grade 1  Astra          1
# Grade 2  Ben Sinuka     2
#          Fumisukoma     5
#          Isaac Booi     3
#          Sandwater      3
#          Seyisi         2
# Grade 3  Ben Sinuka     3
#          Fumisukoma    21
#          Isaac Booi     8
# Name: Mcode, dtype: int64

# %% [markdown]
# ### Improvement of 'Good Readers'

# %%
# Reading total is 128
# children["June - Reading"] = children["June - Blends"] + children["June - Sight Words"] + children['June - Read Sentences'] + children["June - Read Story"] + children["June - Story Comprehension"]

df_good_readers = primary[(primary['On The Programme'] == 'Yes') & (primary['Jan - Sounds and Phonics'] > 35) & (primary['Jan - Reading'] >= 50)]
columns = ["June - Sight Words Improvement","June - Read Story Improvement", "June - Reading Improvement"]
df_good_readers.groupby('Schools')[columns].mean().sort_values("June - Reading Improvement", ascending=False)
# Out:
#             June - Sight Words Improvement  June - Read Story Improvement  \
# Schools
# Astra                             4.000000                      40.000000
# Ben Sinuka                       11.000000                      20.000000
# Fumisukoma                        4.230769                      25.153846
# Seyisi                            7.500000                      19.500000
# Isaac Booi                        0.454545                      -0.727273
# Sandwater                         0.000000                       0.000000
#
#             June - Reading Improvement
# Schools
# Astra                        45.000000
# Ben Sinuka                   37.800000
# Fumisukoma                   32.000000
# Seyisi                       29.500000
# Isaac Booi                    3.181818
# Sandwater                     0.000000

# %% [markdown]
# # Beginner Writers Performance
# ##### Definted as knowing 90% of their phonics/sounds and having an initial writing score above 40%

# %% [markdown]
# ### Number of Beginner Writers

# %%
# Writing total is 87

df_good_writers = primary[(primary['On The Programme'] == 'Yes') & (primary['Jan - Sounds and Phonics'] > 35) & (primary['Jan - Writing'] > 34)]
df_good_writers.groupby(['Grade','Schools'])['Mcode'].count()
# Out:
# Grade    Schools
# Grade 1  Astra           10
#          Charles Duna     4
#          Empumalanga      1
#          Fumisukoma       2
#          Isaac Booi       4
#          Sandwater        2
# Grade 2  Ben Sinuka       8
#          Fumisukoma      26
#          Isaac Booi      15
#          Sandwater        8
#          Seyisi          11
# Grade 3  Ben Sinuka      12
#          Fumisukoma      29
#          Isaac Booi      18
#          Seyisi           3
# Name: Mcode, dtype: int64

# %% [markdown]
# ### Performance of Beginner Writers

# %%
# Writing total is 87

df_good_writers = primary[(primary['On The Programme'] == 'Yes') & (primary['Jan - Sounds and Phonics'] > 35) & (primary['Jan - Writing'] > 34)]
columns = ["June - Write Sentence Improvement","June - Write CVCs", "June - Writing Improvement"]
df_good_writers.groupby('Schools')[columns].mean().sort_values("June - Writing Improvement", ascending=False)
# Out:
#               June - Write Sentence Improvement  June - Write CVCs  \
# Schools
# Charles Duna                          21.250000          12.750000
# 3771           Jasmine Lodewyk              Yes            23.0        243.0
# 3779              Zikhona Gomo              Yes            24.0        246.0
# 307               Alizwa Tsili              Yes            17.0        116.0
# 318               Alizwa Tsili              Yes            17.0        127.0
# 407             Asenathi Phiri              Yes            20.0         93.0
# 430             Noluyolo Nyati              Yes            16.0        123.0
# 443           Nosipho Gxasheka              Yes            18.0        144.0
# 444           Nosipho Gxasheka              Yes            17.0        151.0
# 3275          Nosipho Gxasheka              Yes            16.0        120.0
# 451            Phaphama Kolisi              Yes            16.0        110.0
# 3289              Sinazo Jwara              Yes            20.0        114.0
# 3292              Sinazo Jwara              Yes            20.0        104.0
# 387                        NaN               No             NaN        159.0
#
#       June - Total
# 2604         236.0
# 457          251.0
# 2610         235.0
# 2611         236.0
# 2420         250.0
# 2812         257.0
# 1698         234.0
# 1064         244.0
# 1694         263.0
# 1862         260.0
# 1539         229.0
# 2161         248.0
# 2173         246.0
# 2517         253.0
# 2822         239.0
# 1614         248.0
# 1627         230.0
# 1628         243.0
# 1635         265.0
# 3477         227.0
# 2220         228.0
# 2222         233.0
# 2224         245.0
# 1657         250.0
# 1664         232.0
# 2540         255.0
# 2283         242.0
# 2287         246.0
# 1217         249.0
# 2511         259.0
# 2533         232.0
# 2973         239.0
# 2900         243.0
# 2598         227.0
# 3771         242.0
# 3779         257.0
# 307          265.0
# 318          262.0
# 407          263.0
# 430          246.0
# 443          230.0
# 444          231.0
# 3275         260.0
# 451          230.0
# 3289         265.0
# 3292         236.0
# 387          254.0

# %% [markdown]
# ### Number of Graduates

# %%
graduates = children[children['June - Total'] > 224]
graduates['Mcode'].nunique()
# Out:
# 47

# %% [markdown]
# ### Graduates per Grade & School

# %%
graduates = children[children['June - Total'] > 224]
graduates.groupby(['Grade', 'Schools'])['Mcode'].count()
# Out:
# Grade    Schools
# Grade 1  Astra            1
#          Charles Duna     1
#          Fumisukoma       1
# Grade 2  Ben Sinuka       1
#          Fumisukoma       3
#          Isaac Booi       1
#          Sandwater        2
#          Seyisi           7
# Grade 3  Ben Sinuka       4
#          Fumisukoma      18
#          Isaac Booi       4
#          Seyisi           4
# Name: Mcode, dtype: int64

# %% [markdown]
# # Top Performing Children

# %%
top_improved_children = children[['Mcode', 'Full Name', 'Schools', 'Grade', 'LC Name', 'Jan - Total', 'June - Total', 'June - Total Improvement']].sort_values('June - Total Improvement', ascending=False).head(50)
top_improved_children
# Out:
#       Mcode                 Full Name       Schools    Grade  \
# 407    8276            Nodikida Azoma        Seyisi  Grade 2
# 1698   4550              Kame Yamkela  Charles Duna  Grade 1
# 3289   1564         Anothando Tyhotha        Seyisi  Grade 3
# 307    2084        Matshangane Sesona        Seyisi  Grade 2
# 1635   4561              George Avela    Fumisukoma  Grade 2
# 1539   5661            Ntamo Ahlumile    Fumisukoma  Grade 1
# 3275    920          Rala Kungentando        Seyisi  Grade 3
# 2188   4552               Venani Lulo  Charles Duna  Grade 1
# 318    2137             Solomon Umile        Seyisi  Grade 2
# 2508   4466              Siyona Buhle    Ben Sinuka  Grade 2
# 3390                      58.0
# 664                       57.0
# 3146                      57.0
# 1502                      56.0
# 3381                      50.0

# %% [markdown]
# ### Grade 1: Top 10

# %%
top_improved_grade1_children = children[children['Grade'] == 'Grade 1'][improvement_columns_detailed].sort_values('June - Total Improvement', ascending=False).head(10)
top_improved_grade1_children
# Out:
#              Full Name       Schools    Grade                   LC Name  \
# 1698      Kame Yamkela  Charles Duna  Grade 1             Lutho Ngqokwe
# 1539    Ntamo Ahlumile    Fumisukoma  Grade 1               Elam Xalipi
# 2188       Venani Lulo  Charles Duna  Grade 1  Nandipha Princess Brikwa
# 1540  Fulatela Luphawu    Fumisukoma  Grade 1               Elam Xalipi
# 2146    Nxawe Lingomso     Ebongweni  Grade 1              Zintle Dyesi
# 1913  Hoofman Bohlokoa     Ebongweni  Grade 1         Ncebakazi Sithako
# 2340     Haarhoff Lera         Astra  Grade 1             Shenaaz Britz
# 2411   Xopa Uyathandwa        Molefe  Grade 1             Babalwa Lindi
# 926   Mbombela Lulonke   Empumalanga  Grade 1             Siviwe Sidiba
# 2122  Gudwana Anesipho     Ebongweni  Grade 1              Zintle Dyesi
#
#       June - Listen First Sound Improvement  June - Phonics Improvement  \
# 1698                                    1.0                         8.0
# 1539                                    0.0                         3.0
# 2188                                    5.0                        16.0
# 1540                                    0.0                         4.0
# 2146                                   10.0                        21.0
# 1913                                    8.0                        26.0
# 2340                                    0.0                         3.0
# 2411                                    2.0                        17.0
# 926                                     0.0                         3.0
# 2122                                    3.0                        22.0
#
#       June - Sight Words Improvement  June - Read Story Improvement  \
# 1698                            23.0                           80.0
# 1539                            24.0                           56.0
# 2188                            18.0                           56.0
# 1540                            16.0                           40.0
# 2146                             7.0                           11.0
# 1913                            10.0                            0.0
# 2340                            20.0                            8.0
# 2411                            21.0                            6.0
# 926                             17.0                           43.0
# 2122                             4.0                            4.0
#
#       June - Written Letters Improvement  June - Write Sentence Improvement  \
# 1698                                 4.0                               20.0
# 1539                                 1.0                               36.0
# 2188                                 6.0                               29.0
# 1540                                 3.0                               33.0
# 2146                                18.0                               31.0
# 1913                                23.0                               14.0
# 2340                                 2.0                               39.0
# 2411                                14.0                                8.0
# 926                                  5.0                                0.0
# 2122                                20.0                               25.0
#
#       June - Total Improvement
# 1698                     169.0
# 1539                     142.0
# 2188                     135.0
# 1540                     125.0
# 2146                     124.0
# 1913                     121.0
# 2340                     111.0
# 2411                     109.0
# 926                      107.0
# 2122                     104.0

# %% [markdown]
# ### Grade 2: Top 10

# %%
top_improved_grade2_children = children[children['Grade'] == 'Grade 2'][improvement_columns_detailed].sort_values('June - Total Improvement', ascending=False).head(10)
top_improved_grade2_children
# Out:
#                      Full Name     Schools    Grade              LC Name  \
# 407             Nodikida Azoma      Seyisi  Grade 2       Asenathi Phiri
# 307         Matshangane Sesona      Seyisi  Grade 2         Alizwa Tsili
# 1635              George Avela  Fumisukoma  Grade 2      Nandipha Putela
# 318              Solomon Umile      Seyisi  Grade 2         Alizwa Tsili
# 2508              Siyona Buhle  Ben Sinuka  Grade 2         Sinazo Moabi
# 2517                                    4.0                        19.0
# 2611                                    0.0                         5.0
# 387                                     0.0                         1.0
#
#       June - Sight Words Improvement  June - Read Story Improvement  \
# 3289                            16.0                           79.0
# 3275                            11.0                           80.0
# 430                             18.0                           70.0
# 2220                             1.0                           62.0
# 2221                            19.0                           53.0
# 2825                             3.0                           59.0
# 2616                            22.0                           16.0
# 2517                             4.0                           33.0
# 2611                             0.0                           79.0
# 387                              9.0                           58.0
#
#       June - Written Letters Improvement  June - Write Sentence Improvement  \
# 3289                                 0.0                               17.0
# 3275                                 8.0                               23.0
# 430                                  0.0                               20.0
# 2220                                 5.0                               22.0
# 2221                                 1.0                               17.0
# 2825                                 6.0                               27.0
# 2616                                 4.0                               25.0
# 2517                                 4.0                               27.0
# 2611                                 0.0                                8.0
# 387                                  3.0                               17.0
#
#       June - Total Improvement
# 3289                     151.0
# 3275                     140.0
# 430                      123.0
# 2220                     118.0
# 2221                     117.0
# 2825                     103.0
# 2616                     101.0
# 2517                     101.0
# 2611                      98.0
# 387                       95.0

# %%
# LC Improvement Columns by School
#### This creates an HTML for each school w/ each row being an LC and the average result of their kids for each improvement column

# %%
# Get the unique schools
unique_schools = children['Schools'].unique()

for school in unique_schools:
    # Filter dataframe for each school and 'On The Programme' == 'Yes'
    df_school = children[(children['Schools'] == school) & (children['On The Programme'] == 'Yes')]
    
    # Group by 'LC Name', calculate the mean, and sort values
    result = df_school.groupby('LC Name')[improvement_columns].mean().sort_values('June - Total Improvement', ascending=False)
    
    # Convert the result dataframe to html and save in a file
    result.to_html(f"{school.replace(' ', '_')}_Results.html")

# %%
# June Results & Improvement per LC
#### This creates HTML files for each LC and all of their kids performance.

# %%
import os

# Lists of columns to keep in each CSV
columns_to_keep1 = ['LC Name', 'Full Name', 'Grade','Total Sessions', 'June - Listen First Sound', 'June - Listen Word', 'June - Phonics', 'June - Blends', 
                    'June - Sight Words', 'June - Read Sentences', 'June - Read Story', 
                    'June - Written Letters',
                    'June - Write CVCs', 'June - Write Sentences', 'June - Total']

# Replace these with your second list of columns
columns_to_keep2 = ["LC Name", "Full Name", "Grade","Total Sessions","June - Listen First Sound Improvement","June - Listen Word Improvement", "June - Phonics Improvement","June - Blends Improvement","June - Sight Words Improvement", "June - Read Sentences Improvement", "June - Read Story Improvement", "June - Written Letters Improvement", "June - Write CVCs Improvement", "June - Write Sentence Improvement", "June - Total Improvement" ]
# Create a new directory for these HTML files, if it doesn't already exist
os.makedirs('June Results HTML', exist_ok=True)

# Loop through each unique 'LC Name'
for lc_name, group in children.groupby('LC Name'):
    # Filter the groups
    filtered_group1 = group[columns_to_keep1].sort_values('Full Name')
    filtered_group2 = group[columns_to_keep2].sort_values('Full Name')

    # Convert these DataFrames to HTML tables and concatenate them with a line break in between
    html_table1 = filtered_group1.to_html(index=False)
    html_table2 = filtered_group2.to_html(index=False)
    combined_html = html_table1 + '<br>'*2 + html_table2

    # Create the HTML filename
    filename = os.path.join('June Results HTML', f'{lc_name}.html')

    # Save the HTML content to the file
    with open(filename, 'w') as f:
        f.write(combined_html)
